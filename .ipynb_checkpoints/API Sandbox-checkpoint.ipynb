# %%
import numpy as np
import pandas as pd
import geopandas as gp
import requests
import seaborn as sns
# Out:
# /Users/ianstuart/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# test requests module
payload = {'key1': 'value1', 'key2': 'value2'}

r = requests.get('http://httpbin.org/get', params=payload)
print r.url
# Out:
# http://httpbin.org/get?key2=value2&key1=value1

# %% [markdown]
# ### Get census tract centroids for approximate study area

# %%
# read census tract geojson (source: )
ct = gp.read_file('2010 Census Tracts.geojson')
ct.head()
# Out:
#   boro_code boro_ct_2010      boro_name cdeligibil ct_2010 ctlabel  \
# 0         5      5000900  Staten Island          I  000900       9
# 1         5      5007400  Staten Island          I  007400      74
# 2         1      1009800      Manhattan          I  009800      98
# 3         1      1010000      Manhattan          I  010000     100
# 4         1      1010200      Manhattan          I  010200     102
#
#                                             geometry ntacode  \
# 0  (POLYGON ((-74.07920577013245 40.6434307837456...    SI22
# 1  (POLYGON ((-74.05974734759452 40.5938486115672...    SI14
# 2  (POLYGON ((-73.96432543478758 40.7563815309909...    MN19
# 3  (POLYGON ((-73.96802436915851 40.7595781400528...    MN19
# 4  (POLYGON ((-73.97124277307127 40.7609364184790...    MN17
#
#                                      ntaname  puma     shape_area  \
# 0  West New Brighton-New Brighton-St. George  3903  2497009.69813
# ...

# %%
# list of NTAs to filter by to approximate study area
# tracts will actually be identified by number using walking distance analysis
ntas = ['North Side-South Side', 'East Williamsburg', 'Stuyvesant Heights', 'Bedford', 'Bushwick South', 'Williamsburg']

# create dataframe with only the desired tracts
ct_bk = ct[(ct.boro_name == 'Brooklyn') & (ct['ntaname'].isin(ntas))]

print "Total tracts in Brooklyn study area: " + str(len(ct_bk))
# Out:
# Total tracts in Brooklyn study area: 88

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# quick plot of the study area
fig, ax = plt.subplots(figsize=(8,8))
ct_bk.plot(ax=ax)

# %%
# create new column containing tract polygon centroids, to use as approximate trip origins (lat/lon)
ct_bk['centroid'] = ct_bk.geometry.centroid
ct_bk.head()
# Out:
# /Users/ianstuart/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#     boro_code boro_ct_2010 boro_name cdeligibil ct_2010 ctlabel  \
# 88          3      3024500  Brooklyn          E  024500     245
# 92          3      3024900  Brooklyn          E  024900     249
# 100         3      3026300  Brooklyn          E  026300     263
# 103         3      3026700  Brooklyn          I  026700     267
# 105         3      3026900  Brooklyn          E  026900     269
#
#                                               geometry ntacode  ntaname  puma  \
# 88   (POLYGON ((-73.9495568871113 40.68039040292329...    BK75  Bedford  4003
# ...

# %%
# get longitude coordinate of the first entry
ct_bk.centroid.iloc[0].x
# Out:
# -73.95190111786707

# %% [markdown]
# ### Get census tract centroids for Manhattan (destination tracts)

# %%
# create new dataframe with all MN census tracts
ct_mn = ct[ct.boro_name == 'Manhattan']
print "Total census tracts in Manhattan: " + str(len(ct_mn))
# Out:
# Total census tracts in Manhattan: 288

# %%
# quick plot of MN tracts
fig, ax = plt.subplots(figsize=(5,10))
ct_mn.plot(ax=ax, )

# %%
# create a centroid column
ct_mn['centroid'] = ct.geometry.centroid
# Out:
# /Users/ianstuart/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %% [markdown]
# ### Test api request using first entry from BK and MN data as origin and destination

# %%
# set origin and destination coordinate variables
orig_lat = ct_bk.centroid.iloc[0].y
orig_lon = ct_bk.centroid.iloc[0].x
dest_lat = ct_mn.centroid.iloc[1].y
dest_lon = ct_mn.centroid.iloc[1].x

payload = {
    'locations': [
        {'lat':orig_lat,'lon':orig_lon}, 
        {'lat':dest_lat,'lon':dest_lon}
    ],
    'costing': 'multimodal',
}

api_key = {'api_key': 'mapzen-a75iBa1'}

r = requests.get('https://valhalla.mapzen.com/route', json=payload, params=api_key)
print r.url
r.json()
# Out:
# https://valhalla.mapzen.com/route?api_key=mapzen-a75iBa1
# {u'trip': {u'language': u'en-US',
#   u'legs': [{u'maneuvers': [{u'begin_shape_index': 0,
#       u'end_shape_index': 1,
#       u'instruction': u'Walk west on Jefferson Avenue.',
#       u'length': 0.16,
#       u'street_names': [u'Jefferson Avenue'],
#       u'time': 112,
#       u'travel_mode': u'pedestrian',
#       u'travel_type': u'foot',
#       u'type': 3,
#       u'verbal_pre_transition_instruction': u'Walk west on Jefferson Avenue for 200 meters.'},
#      {u'begin_shape_index': 1,
#       u'end_shape_index': 10,
#       u'instruction': u'Turn right onto Bedford Avenue.',
#       u'length': 0.74,
#       u'street_names': [u'Bedford Avenue'],
#       u'time': 522,
#       u'travel_mode': u'pedestrian',
#       u'travel_type': u'foot',
#       u'type': 10,
#       u'verbal_post_transition_instruction': u'Continue for 700 meters.',
#       u'verbal_pre_transition_instruction': u'Turn right onto Bedford Avenue.',
# ...

# %%
#### route shape decoding function (https://mapzen.com/documentation/mobility/decoding/)

import sys

# six degrees of precision in valhalla
inv = 1.0 / 1e6;

# decode an encoded string
def decode(encoded):
  decoded = []
  previous = [0,0]
  i = 0
  #for each byte
  while i < len(encoded):
    #for each coord (lat, lon)
    ll = [0,0]
    for j in [0, 1]:
      shift = 0
      byte = 0x20
      #keep decoding bytes until you have this coord
      while byte >= 0x20:
        byte = ord(encoded[i]) - 63
        i += 1
        ll[j] |= (byte & 0x1f) << shift
        shift += 5
      #get the final value adding the previous offset and remember it for the next
      ll[j] = previous[j] + (~(ll[j] >> 1) if ll[j] & 1 else (ll[j] >> 1))
      previous[j] = ll[j]
    #scale by the precision and chop off long coords also flip the positions so
    #its the far more standard lon,lat instead of lat,lon
    decoded.append([float('%.6f' % (ll[1] * inv)), float('%.6f' % (ll[0] * inv))])
  #hand back the list of coordinates
  return decoded

# %%
import json
import shapely as sh

response = r.json()
# access the encoded route geometry in the json/dictionary response
route_shape_encoded = response['trip']['legs'][0]['shape']

# %%
# decode the route shape from the json response
route_shape = decode(route_shape_encoded)

# convert list of lat/lon pairs into shapely point objects
points = [sh.geometry.Point(x) for x in route_shape]
# print points

# convert the points into a shapely linestring object
route_linestring = sh.geometry.LineString(points)
x, y = route_linestring.xy
# print x, y

# plot the linestring
fig, ax = plt.subplots(figsize=(8,16))
ax.plot(x, y, color='b',
    linewidth=4, solid_capstyle='round')
ct_mn.plot(ax=ax, linewidth=0.5)
ct_bk.plot(ax=ax, linewidth=0.5)

# %%
#### Check crs information?

# %% [markdown]
# ### Test automated requests using one Brooklyn census tract and first 10 Manhattan census tracts (one to many)

# %%
# use ratelimiter package to stay within mapzen api limits (max 2 calls per second)
from ratelimiter import RateLimiter

rate_limiter = RateLimiter(max_calls=1, period=1)

# %%
# set origin coordinate variables
orig_lat = ct_bk.centroid.iloc[0].y
orig_lon = ct_bk.centroid.iloc[0].x

api_key = {'api_key': 'mapzen-a75iBa1'}

# empty array to store travel times
times = []

# function to get api responses using destination tract centroid as the parameter
def get_responses(dest_centroid):
    
    dest_lat = dest_centroid.y
    dest_lon = dest_centroid.x    
    
    payload = {
        'locations': [
            {'lat':orig_lat,'lon':orig_lon}, 
            {'lat':dest_lat,'lon':dest_lon}
        ],
        'costing': 'multimodal',
    }

    r = requests.get('https://valhalla.mapzen.com/route', json=payload, params=api_key)
    response = r.json()
    time = response['trip']['summary']['time']
    times.append(time)

# call the function for two destination tracts, once per second, to stay within api limit    
for i in np.arange(0, 10, 2):
    with rate_limiter:
        ct_mn.centroid[i:i+2].apply(get_responses)

# %%
print "Travel times in seconds to first ten Manhattan census tracts:\n", times
# Out:
# Travel times in seconds to first ten Manhattan census tracts:
# [3334, 3281, 3193, 3151, 2505, 2816, 3696, 3263, 3311, 3331]

# %%
# convert times from seconds to minutes
times_min = np.asarray(times)/60
print "Travel times in minutes:", times_min
# Out:
# Travel times in minutes: [55 54 53 52 41 46 61 54 55 55]

# %%
ct_mn['times'] = np.nan
ct_mn.times[:10] = times_min
# Out:
# /Users/ianstuart/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/ianstuart/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/ianstuart/anaconda/lib/python2.7/site-packages/pandas/core/series.py:749: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
ct_mn.head()
# Out:
#   boro_code boro_ct_2010  boro_name cdeligibil ct_2010 ctlabel  \
# 2         1      1009800  Manhattan          I  009800      98
# 3         1      1010000  Manhattan          I  010000     100
# 4         1      1010200  Manhattan          I  010200     102
# 5         1      1010400  Manhattan          I  010400     104
# 6         1      1011300  Manhattan          I  011300     113
#
#                                             geometry ntacode  \
# 2  (POLYGON ((-73.96432543478758 40.7563815309909...    MN19
# 3  (POLYGON ((-73.96802436915851 40.7595781400528...    MN19
# 4  (POLYGON ((-73.97124277307127 40.7609364184790...    MN17
# 5  (POLYGON ((-73.97445730550224 40.7622930835248...    MN17
# 6  (POLYGON ((-73.98411754823195 40.7548420534646...    MN17
#
#                    ntaname  puma     shape_area     shape_leng  \
# 2  Turtle Bay-East Midtown  3808  1906016.35002  5534.19981063
# 3  Turtle Bay-East Midtown  3808  1860938.37721  5692.16873705
# ...

# %%
# plot sample destination census tracts colored by travel time

fig, ax = plt.subplots(figsize=(8,16))
ct_mn.plot(ax=ax, color='w', linewidth=0.5)
ct_mn[:10].plot(ax=ax, linewidth=0.5, column='times', cmap='YlOrRd')
# ct_bk.plot(ax=ax, linewidth=0.5)

# %% [markdown]
# ### Test automated requests using one Brooklyn census tract and 10 random Manhattan census tracts
# #### Get fastest route with and without the L
# #### Save the time differences and route shape in a new geodataframe

# %%
columns=['orig', 'dest', 'time', 'time_alt', 'time_diff', 'percent_change', 'route', 'route_alt']

# %%
# set origin coordinate variables
orig_tract_row = ct_bk.iloc[20]
orig_tract_row = ct_bk.iloc[20]
orig_lat = orig_tract_row.centroid.y
orig_lon - orig_tract_row.centroid.x

result = []

# function to get api responses using destination tract centroid as the parameter
# saves difference in travel time with and without the L (positive value means increase in travel time)
# adds each time, the absolute change, the percentage change, and the alternate route shapes to the 'result' array 
# also specifies departure date/time for 9am on a Monday (morning rush hour)
def get_responses(dest_tract_row):
    
    dest_lat = dest_tract_row.centroid.y
    dest_lon = dest_tract_row.centroid.x
    
    payload = {
        'locations': [
            {'lat':orig_lat,'lon':orig_lon}, 
            {'lat':dest_lat,'lon':dest_lon}
        ],
        'costing': 'multimodal',
    }

    payload_alt = {
        'locations': [
            {'lat':orig_lat,'lon':orig_lon}, 
            {'lat':dest_lat,'lon':dest_lon}
        ],
        'costing': 'multimodal',
        'costing_options': {
            "transit": {
                "filters": {
                    "stops": {
                        "ids": [
                            "s-dr5rswb4zp-1av<l06n",
                            "s-dr5rsrhyn3-3av<l05n",
                            "s-dr5rsr9975-unionsq~14st<l03n",
                            "s-dr5ru0j0jv-6av<l02n",
                            "s-dr5ru02yqu-8av<l01n"
                        ],
                        "action":"exclude"
                    }
                }
            }
        },
        'date_time': {
            'type': 1,
            'value': '2017-03-13T09:00'
        }
    }
    
    r = requests.get('https://valhalla.mapzen.com/route', json=payload, params=api_key)
    r_alt = requests.get('https://valhalla.mapzen.com/route', json=payload_alt, params=api_key)

    response = r.json()
    response_alt = r_alt.json()
    
    orig = orig_tract_row.boro_ct_2010
    dest = dest_tract_row.boro_ct_2010
    time = response['trip']['summary']['time']
    time_alt = response_alt['trip']['summary']['time']
    time_diff = time_alt - time
    percent_change = 1.*time_diff/time
    route_encoded = response['trip']['legs'][0]['shape']
    route_alt_encoded = response_alt['trip']['legs'][0]['shape']
    
    result.append([orig, dest, time, time_alt, time_diff, percent_change, route_encoded, route_alt_encoded])
    return result
    
# set seed for random selection of MN tracts
np.random.seed(0)

# call the function for once per second (two separate requests from api), to stay within api limit
# choose 5 random MN destination tracts
for i in range(10):
    # 288 tracts in Manhattan
    j = np.random.randint(0, 288)
    with rate_limiter:
#         print ct_mn.iloc[j].centroid
        data = get_responses(ct_mn.iloc[j])

print result
# Out:
# [[u'3050300', u'1018800', 2665, 3565, 900, 0.33771106941838647, u'}_{slAvnk`lCab@vDkk@bF_m@rFhHnfB?fw@F??NOpp@?vC?hC?fDUhCOvCm@vCe@hCe@hCe@fCm@hCu@vC{@hCsAhC}@xBkAfCyvDtfHuzQjh]{@zA}@hBkAxB{@xB}@jBsAxBu@vC{@hCsAxB}@fCkAxC{@fCsAfDkAxC}@fDmxElbO??wuBzwG??ixBn~Gu@|@??cBsFrAiClAwDrEgNnDkKzAuE{F\\?^F?yBLcB?aBNcB?yB?cB?aBOsAMcB_@aBMcBOsAm@cBMaBm@kA_@_uGcjEG?agE{pCMO{zDkgCG?ocI_lF{@{@}@m@e@}@{@{@}@}@e@{@e@kAe@}@m@{Ae@kAe@{@W{AM{Am@kAOkAsKgw@?OuJqq@UyBe@yBWiBe@{Ae@iBm@{Ae@{A{@{A}@kAe@{@}@{A{@}@kA{@}@m@kA}@qhHmxEUMiqIauFOO_}Ia_GMM}tIkxFUOmmJajGOMw`KyxGOOqrHc_FMM{rGghEOMa`FacDN???di@ccBjz@ekCcVuOmO}J', u'}_{slAvnk`lC`Hm@fm@sFvH~eBbLfjCzA~]xAdZrAb[|@bQbAjVrAdYzAb\\bAdYrArFjA|U^|I\\tE|@dOfCpf@t@zLd@|I\\~Hze@zVnh@fYrd@zUlExBt@yCl@yBcAk@?Lw]twAO|@Uz@W^Oj@k@|@O\\Ul@Ol@Wl@e@l@Ul@OLm@l@M\\Wl@g|@ziAe@|@e@l@m@z@e@|@Oz@m@l@e@zAUz@e@|@e@z@WjAM|@m@jAO|@UjAeoIvqa@ufBhvIWhBe@zAe@hBWzAe@jBe@xAUjBe@xAm@jBe@hBe@jBe@hBm@zAe@hBe@jByBpGOjAm@jAMzAm@zAe@jAOzAm@zAOjAe@hBm@jBMxAm@jBe@xAOjBm@zA{ZpyAG^q`AnvEex@j{DG\\ox
# ...

# %%
result_df = gp.GeoDataFrame(result, columns=columns)
result_df
# Out:
#       orig     dest  time  time_alt  time_diff  percent_change  \
# 0  3050300  1018800  2665      3565        900        0.337711
# 1  3050300  1004500  1624      1792        168        0.103448
# 2  3050300  1008603  2171      2141        -30       -0.013819
# 3  3050300  1007500  1616      2516        900        0.556931
# 4  3050300  1017300  2749      3438        689        0.250637
# 5  3050300  1019900  2805      3554        749        0.267023
# 6  3050300  1014602  2011      2791        780        0.387867
# 7  3050300  1009600  1689      2598        909        0.538188
# 8  3050300  1020300  2868      3678        810        0.282427
# 9  3050300  1018100  2375      3492       1117        0.470316
#
#                                                route  \
# 0  }_{slAvnk`lCab@vDkk@bF_m@rFhHnfB?fw@F??NOpp@?v...
# 1  }_{slAvnk`lCab@vDkk@bF_m@rFhHnfB?fw@F??NOpp@?v...
# 2  }_{slAvnk`lCab@vDvH~eBbLxhCiWfC?^ocVsGkbLjeEO?...
# 3  }_{slAvnk`lCab@vDkk@bF_m@rFhHnfB?fw@F??NOpp@?v...
# ...

# %%
result_df.iloc[:,-2:] = result_df.iloc[:,-2:].applymap(decode)

# %%
result_df
# Out:
#       orig     dest  time  time_alt  time_diff  percent_change  \
# 0  3050300  1018800  2665      3565        900        0.337711
# 1  3050300  1004500  1624      1792        168        0.103448
# 2  3050300  1008603  2171      2141        -30       -0.013819
# 3  3050300  1007500  1616      2516        900        0.556931
# 4  3050300  1017300  2749      3438        689        0.250637
# 5  3050300  1019900  2805      3554        749        0.267023
# 6  3050300  1014602  2011      2791        780        0.387867
# 7  3050300  1009600  1689      2598        909        0.538188
# 8  3050300  1020300  2868      3678        810        0.282427
# 9  3050300  1018100  2375      3492       1117        0.470316
#
#                                                route  \
# 0  [[-73.947388, 40.712207], [-73.94748, 40.71276...
# 1  [[-73.947388, 40.712207], [-73.94748, 40.71276...
# 2  [[-73.947388, 40.712207], [-73.94748, 40.71276...
# 3  [[-73.947388, 40.712207], [-73.94748, 40.71276...
# ...

# %%
# convert each lat/lon pair in routes into shapely point objects
result_df.iloc[:,-2:] = result_df.iloc[:,-2:].applymap(lambda x: [sh.geometry.Point(y) for y in x])

# convert the points into shapely linestring objects
result_df.iloc[:,-2:] = result_df.iloc[:,-2:].applymap(lambda x: sh.geometry.LineString(x))

result_df
# Out:
#       orig     dest  time  time_alt  time_diff  percent_change  \
# 0  3050300  1018800  2665      3565        900        0.337711
# 1  3050300  1004500  1624      1792        168        0.103448
# 2  3050300  1008603  2171      2141        -30       -0.013819
# 3  3050300  1007500  1616      2516        900        0.556931
# 4  3050300  1017300  2749      3438        689        0.250637
# 5  3050300  1019900  2805      3554        749        0.267023
# 6  3050300  1014602  2011      2791        780        0.387867
# 7  3050300  1009600  1689      2598        909        0.538188
# 8  3050300  1020300  2868      3678        810        0.282427
# 9  3050300  1018100  2375      3492       1117        0.470316
#
#                                                route  \
# 0  LINESTRING (-73.947388 40.712207, -73.94748 40...
# 1  LINESTRING (-73.947388 40.712207, -73.94748 40...
# 2  LINESTRING (-73.947388 40.712207, -73.94748 40...
# 3  LINESTRING (-73.947388 40.712207, -73.94748 40...
# ...

# %%
# load borough boundaries for plotting
boros = gp.read_file('Data/Borough Boundaries.geojson')

# %%
fig, ax = plt.subplots(figsize=(10,12))
boros.plot(ax=ax, color='w', linewidth=0.5)
# ct_mn.plot(ax=ax, linewidth=0.5)
# ct_bk.plot(ax=ax, linewidth=0.5)
plt.ylim(40.65, 40.83)
plt.xlim(-74.05, -73.85)

# plot the route linestrings
for route in result_df['route']:
    x, y = route.xy
    ax.plot(x, y, color='b',
        linewidth=3, alpha=0.7, solid_capstyle='round')

# plot the alternate route linestrings
for route_alt in result_df['route_alt']:
    x, y = route_alt.xy
    x = [(k - .0005) for k in x]
    y = [(k - .0005) for k in y]
    ax.plot(x, y, color='r',
        linewidth=3, alpha=0.7, solid_capstyle='round')

# %%
fig, ax = plt.subplots(figsize=(10,12))
boros.plot(ax=ax, color='w', linewidth=0.5)
# ct_mn.plot(ax=ax, linewidth=0.5)
# ct_bk.plot(ax=ax, linewidth=0.5)
plt.ylim(40.65, 40.83)
plt.xlim(-74.05, -73.85)

# plot the alternate route linestrings colored by whether time difference is positive
for index, row in result_df.iterrows():
    route_alt = row['route_alt']
    x, y = route_alt.xy   
    if row['time_diff'] > 0:
        ax.plot(x, y, color='r',
            linewidth=3, alpha=0.7, solid_capstyle='round') 
    else:
        ax.plot(x, y, color='b',
            linewidth=3, alpha=0.7, solid_capstyle='round')

# %%
# normalize time_diff column for colormapping
### this needs fixing to account for negative time_diff values
result_df['time_diff_norm'] = result_df['time_diff'].apply(
    lambda x: 1.*(x - result_df['time_diff'].min())/(result_df['time_diff'].max() - result_df['time_diff'].min()))
result_df
# Out:
#       orig     dest  time  time_alt  time_diff  percent_change  \
# 0  3050300  1018800  2665      3565        900        0.337711
# 1  3050300  1004500  1624      1792        168        0.103448
# 2  3050300  1008603  2171      2141        -30       -0.013819
# 3  3050300  1007500  1616      2516        900        0.556931
# 4  3050300  1017300  2749      3438        689        0.250637
# 5  3050300  1019900  2805      3554        749        0.267023
# 6  3050300  1014602  2011      2791        780        0.387867
# 7  3050300  1009600  1689      2598        909        0.538188
# 8  3050300  1020300  2868      3678        810        0.282427
# 9  3050300  1018100  2375      3492       1117        0.470316
#
#                                                route  \
# 0  LINESTRING (-73.947388 40.712207, -73.94748 40...
# 1  LINESTRING (-73.947388 40.712207, -73.94748 40...
# 2  LINESTRING (-73.947388 40.712207, -73.94748 40...
# 3  LINESTRING (-73.947388 40.712207, -73.94748 40...
# ...

# %%
fig, ax = plt.subplots(figsize=(10,12))
boros.plot(ax=ax, color='w', linewidth=0.5)
plt.ylim(40.65, 40.83)
plt.xlim(-74.05, -73.85)

# plot the alternate route linestrings colored by relative size of time difference
for index, row in result_df.iterrows():
    route_alt = row['route_alt']
    f = row['time_diff_norm']
    r = 1
    g = f
    b = 0
    x, y = route_alt.xy   
    ax.plot(x, y, color=(r, g, b),
        linewidth=3, alpha=0.5, solid_capstyle='round')

# %%
# normalize percent_change column for colormapping (to values between 0 and 1)
### this needs fixing to account for negative percent values
result_df['percent_change_norm'] = result_df['percent_change'].apply(
    lambda x: 1.*(x - result_df['percent_change'].min())/(result_df['percent_change'].max() - result_df['percent_change'].min()))
result_df
# Out:
#       orig     dest  time  time_alt  time_diff  percent_change  \
# 0  3050300  1018800  2665      3565        900        0.337711
# 1  3050300  1004500  1624      1792        168        0.103448
# 2  3050300  1008603  2171      2141        -30       -0.013819
# 3  3050300  1007500  1616      2516        900        0.556931
# 4  3050300  1017300  2749      3438        689        0.250637
# 5  3050300  1019900  2805      3554        749        0.267023
# 6  3050300  1014602  2011      2791        780        0.387867
# 7  3050300  1009600  1689      2598        909        0.538188
# 8  3050300  1020300  2868      3678        810        0.282427
# 9  3050300  1018100  2375      3492       1117        0.470316
#
#                                                route  \
# 0  LINESTRING (-73.947388 40.712207, -73.94748 40...
# 1  LINESTRING (-73.947388 40.712207, -73.94748 40...
# 2  LINESTRING (-73.947388 40.712207, -73.94748 40...
# 3  LINESTRING (-73.947388 40.712207, -73.94748 40...
# ...

# %%
fig, ax = plt.subplots(figsize=(10,12))
boros.plot(ax=ax, color='w', linewidth=0.5)
plt.ylim(40.65, 40.83)
plt.xlim(-74.05, -73.85)

# plot the alternate route linestrings colored by percentage time difference
for index, row in result_df.iterrows():
    route_alt = row['route_alt']
    # check for negatives
    if row['percent_change_norm'] < 0:
        g = 0
    else:
        g = row['percent_change_norm']
    r = 1
    b = 0
    x, y = route_alt.xy   
    ax.plot(x, y, color=(r, g, b),
        linewidth=3, alpha=0.5, solid_capstyle='round')

# %%
result_df_L = result_df.drop('route_alt', axis=1)
result_df_L = result_df_L.rename(columns={'route': 'geometry'})
result_df_L
# Out:
#    time  time_alt  time_diff  percent_change  \
# 0  2785      3565        780        0.280072
# 1  1761      1792         31        0.017604
# 2  1991      2141        150        0.075339
# 3  1676      2516        840        0.501193
# 4  2359      3438       1079        0.457397
# 5  2835      3554        719        0.253616
# 6  2251      2791        540        0.239893
# 7  1779      2598        819        0.460371
# 8  2958      3678        720        0.243408
# 9  2413      3492       1079        0.447161
#
#                                             geometry  time_diff_norm  \
# 0  LINESTRING (-73.947388 40.712207, -73.94748 40...        0.714695
# 1  LINESTRING (-73.947388 40.712207, -73.947365 4...        0.000000
# 2  LINESTRING (-73.947388 40.712207, -73.94748 40...        0.113550
# 3  LINESTRING (-73.947388 40.712207, -73.94748 40...        0.771947
# 4  LINESTRING (-73.947388 40.712207, -73.94748 40...        1.000000
# ...

# %%
result_df_L.to_file('random10routes_L.geojson', driver='GeoJSON')

# %%
result_df_noL = result_df.drop('route', axis=1)
result_df_noL = result_df_L.rename(columns={'route_alt': 'geometry'})
result_df_noL
# Out:
#    time  time_alt  time_diff  percent_change  \
# 0  2785      3565        780        0.280072
# 1  1761      1792         31        0.017604
# 2  1991      2141        150        0.075339
# 3  1676      2516        840        0.501193
# 4  2359      3438       1079        0.457397
# 5  2835      3554        719        0.253616
# 6  2251      2791        540        0.239893
# 7  1779      2598        819        0.460371
# 8  2958      3678        720        0.243408
# 9  2413      3492       1079        0.447161
#
#                                             geometry  time_diff_norm  \
# 0  LINESTRING (-73.947388 40.712207, -73.94748 40...        0.714695
# 1  LINESTRING (-73.947388 40.712207, -73.947365 4...        0.000000
# 2  LINESTRING (-73.947388 40.712207, -73.94748 40...        0.113550
# 3  LINESTRING (-73.947388 40.712207, -73.94748 40...        0.771947
# 4  LINESTRING (-73.947388 40.712207, -73.94748 40...        1.000000
# ...

# %%
result_df_noL.to_file('random10routes_noL.geojson', driver='GeoJSON')

# %%
fig, ax = plt.subplots(figsize=(10,12))
boros.plot(ax=ax, color='w', linewidth=0.5)
plt.ylim(40.65, 40.83)
plt.xlim(-74.05, -73.85)

# plot destination tracts
for index, row in result_df.iterrows():
    dest_ct = row['dest']
    dest_ix = ct_mn[ct_mn['boro_ct_2010'] == dest_ct].index[0]
    f = row['percent_change_norm']
    r = 1
    g = f
    b = 0
    ct_mn.geometry.loc[dest_ix:dest_ix].plot(
        ax=ax, linewidth=0, color=(r,g,b))

# plot the route linestrings
for route in result_df['route']:
    x, y = route.xy
    ax.plot(x, y, color='b',
        linewidth=3, alpha=0.25, solid_capstyle='round')

# plot the alternate route linestrings
for route_alt in result_df['route_alt']:
    x, y = route_alt.xy
    x = [(k - .0005) for k in x]
    y = [(k - .0005) for k in y]
    ax.plot(x, y, color='r',
        linewidth=3, alpha=0.25, solid_capstyle='round')

# %%
# get average time difference (or percent change) for the tract
# weight each route by the number of commuters, and then average that figure
# identify subway lines used in alternate routes that aren't used in regular routes
